# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/cyrus/Desktop/Titanic/Dataset/train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df2 = df.drop('PassengerId', axis=1)
df2
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df3 =  df2.drop(['SibSp', 'Parch'], axis=1)
df3
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age            Ticket     Fare Cabin Embarked
# 0      male  22.0         A/5 21171   7.2500   NaN        S
# 1    female  38.0          PC 17599  71.2833   C85        C
# 2    female  26.0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0            113803  53.1000  C123        S
# 4      male  35.0            373450   8.0500   NaN        S
# ..      ...   ...               ...      ...   ...      ...
# 886    male  27.0            211536  13.0000   NaN        S
# 887  female  19.0            112053  30.0000   B42        S
# 888  female   NaN        W./C. 6607  23.4500   NaN        S
# 889    male  26.0            111369  30.0000  C148        C
# 890    male  32.0            370376   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
df4 = df3.drop(['Name', 'Ticket'], axis=1)
df4
# Out:
#      Survived  Pclass     Sex   Age     Fare Cabin Embarked
# 0           0       3    male  22.0   7.2500   NaN        S
# 1           1       1  female  38.0  71.2833   C85        C
# 2           1       3  female  26.0   7.9250   NaN        S
# 3           1       1  female  35.0  53.1000  C123        S
# 4           0       3    male  35.0   8.0500   NaN        S
# ..        ...     ...     ...   ...      ...   ...      ...
# 886         0       2    male  27.0  13.0000   NaN        S
# 887         1       1  female  19.0  30.0000   B42        S
# 888         0       3  female   NaN  23.4500   NaN        S
# 889         1       1    male  26.0  30.0000  C148        C
# 890         0       3    male  32.0   7.7500   NaN        Q
#
# [891 rows x 7 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   Fare      891 non-null    float64
#  5   Cabin     204 non-null    object
#  6   Embarked  889 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 48.9+ KB

# %%
df4.sort_values(by='Survived', ascending=False)
# Out:
#      Survived  Pclass     Sex   Age      Fare Cabin Embarked
# 445         1       1    male   4.0   81.8583   A34        S
# 319         1       1  female  40.0  134.5000   E34        C
# 334         1       1  female   NaN  133.6500   NaN        S
# 330         1       3  female   NaN   23.2500   NaN        Q
# 329         1       1  female  16.0   57.9792   B18        C
# ..        ...     ...     ...   ...       ...   ...      ...
# 365         0       3    male  30.0    7.2500   NaN        S
# 371         0       3    male  18.0    6.4958   NaN        S
# 372         0       3    male  19.0    8.0500   NaN        S
# 373         0       1    male  22.0  135.6333   NaN        C
# 890         0       3    male  32.0    7.7500   NaN        Q
#
# [891 rows x 7 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   Fare      891 non-null    float64
#  5   Cabin     204 non-null    object
#  6   Embarked  889 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 48.9+ KB

# %%
plt.scatter(x=df4.Survived, y=df4.Embarked.astype(str))

# %%
df4['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df4['Embarked'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Embarked, Length: 891, dtype: bool

# %%
df4[df4['Embarked'].isna()]
# Out:
#      Survived  Pclass     Sex   Age  Fare Cabin Embarked
# 61          1       1  female  38.0  80.0   B28      NaN
# 829         1       1  female  62.0  80.0   B28      NaN

# %%
df4[df4['Embarked'].isna()].index
# Out:
# Int64Index([61, 829], dtype='int64')

# %%
df5 = df4.drop(df4[df4['Embarked'].isna()].index, axis=0)
df5
# Out:
#      Survived  Pclass     Sex   Age     Fare Cabin Embarked
# 0           0       3    male  22.0   7.2500   NaN        S
# 1           1       1  female  38.0  71.2833   C85        C
# 2           1       3  female  26.0   7.9250   NaN        S
# 3           1       1  female  35.0  53.1000  C123        S
# 4           0       3    male  35.0   8.0500   NaN        S
# ..        ...     ...     ...   ...      ...   ...      ...
# 886         0       2    male  27.0  13.0000   NaN        S
# 887         1       1  female  19.0  30.0000   B42        S
# 888         0       3  female   NaN  23.4500   NaN        S
# 889         1       1    male  26.0  30.0000  C148        C
# 890         0       3    male  32.0   7.7500   NaN        Q
#
# [889 rows x 7 columns]

# %%
plt.bar(df5['Embarked'], df5['Survived'])
# Out:
# <BarContainer object of 889 artists>

# %%
import seaborn as sns

# %%
sns.countplot(data=df5, x='Embarked', hue='Survived')
# Out:
# <AxesSubplot: xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(data=df5, x='Pclass', hue='Survived')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(data=df5, x='Sex', hue='Survived')
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(data=df5, x='Fare', hue='Survived')
# Out:
# <AxesSubplot: xlabel='Fare', ylabel='count'>

# %%
df5.plot.scatter('Survived', 'Fare')
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='Fare'>

# %%
df5.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Fare', 'Cabin', 'Embarked'], dtype='object')

# %%
df5.hist('Age')
# Out:
# array([[<AxesSubplot: title={'center': 'Age'}>]], dtype=object)

# %%
df5['Pclass'].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df5['Sex'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
df5.groupby('Pclass').mean()
# Out:
# /var/folders/hq/k7mytvqj4yx7lm5dy9c9n9lr0000gn/T/ipykernel_4503/3478161901.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df5.groupby('Pclass').mean()
#         Survived        Age       Fare
# Pclass
# 1       0.626168  38.105543  84.193516
# 2       0.472826  29.877630  20.662183
# 3       0.242363  25.140620  13.675550

# %%
df5.groupby(['Sex', 'Pclass', 'Embarked']).mean()
# Out:
# /var/folders/hq/k7mytvqj4yx7lm5dy9c9n9lr0000gn/T/ipykernel_4503/863649665.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df5.groupby(['Sex', 'Pclass', 'Embarked']).mean()
#                         Survived        Age        Fare
# Sex    Pclass Embarked
# female 1      C         0.976744  36.052632  115.640309
#               Q         1.000000  33.000000   90.000000
#               S         0.958333  32.704545   99.026910
#        2      C         1.000000  19.142857   25.268457
#               Q         1.000000  30.000000   12.350000
#               S         0.910448  29.719697   21.912687
#        3      C         0.652174  14.062500   14.694926
#               Q         0.727273  22.850000   10.307833
#               S         0.375000  23.223684   18.670077
# male   1      C         0.404762  40.111111   93.536707
#               Q         0.000000  44.000000   90.000000
#               S         0.354430  41.897188   52.949947
#        2      C         0.200000  25.937500   25.421250
#               Q         0.000000  57.000000   12.350000
#               S         0.154639  30.875889   19.232474
#        3      C         0.232558  25.016800    9.352237
#               Q         0.076923  28.142857   11.924251
#               S         0.128302  26.574766   13.307149

# %%
df_test = pd.read_csv('/Users/cyrus/Desktop/Titanic/Dataset/test.csv')

# %%
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
table = df5.groupby(['Sex', 'Pclass']).mean()
# Out:
# /var/folders/hq/k7mytvqj4yx7lm5dy9c9n9lr0000gn/T/ipykernel_4503/303781360.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   table = df5.groupby(['Sex', 'Pclass']).mean()

# %%
table.loc['female'].loc[1].loc['Q']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [49], line 1
# ----> 1 table.loc['female'].loc[1].loc['Q']
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Q'

# %%
table
# Out:
#                Survived        Age        Fare
# Sex    Pclass
# female 1       0.967391  34.240964  106.693750
#        2       0.921053  28.722973   21.970121
#        3       0.500000  21.750000   16.118810
# male   1       0.368852  41.281386   67.226127
#        2       0.157407  30.740707   19.741782
#        3       0.135447  26.507589   12.661633

# %%
survival_rate = table.loc['male'].loc[3].loc['Q'].Survived > 0.5
survival_rate
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [48], line 1
# ----> 1 survival_rate = table.loc['male'].loc[3].loc['Q'].Survived > 0.5
#       2 survival_rate
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File ~/Desktop/Titanic/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Q'

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
def isSurvived(row):
    sex = row['Sex']
    pclass = row['Pclass']
    # embarked = row['Embarked']
    # return table.loc[sex].loc[pclass].loc[embarked].Survived > 0.5
    return table.loc[sex].loc[pclass].Survived > 0.5

# %%
df_predict = df_test.copy()
df_predict['Survived'] = df5.apply(isSurvived, axis=1)

# %%
df_predict = df_predict[['PassengerId', 'Survived']]
df_predict
# Out:
#      PassengerId Survived
# 0            892    False
# 1            893     True
# 2            894    False
# 3            895     True
# 4            896    False
# ..           ...      ...
# 413         1305    False
# 414         1306    False
# 415         1307    False
# 416         1308     True
# 417         1309     True
#
# [418 rows x 2 columns]

# %%
df_predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     417 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 6.7+ KB

# %%
df_predict = df_predict.fillna('False')

# %%
df_predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 6.7+ KB

# %%
df_predict['Survived'] = df_predict['Survived'].astype(bool)

# %%
df_predict
# Out:
#      PassengerId  Survived
# 0            892     False
# 1            893      True
# 2            894     False
# 3            895      True
# 4            896     False
# ..           ...       ...
# 413         1305     False
# 414         1306     False
# 415         1307     False
# 416         1308      True
# 417         1309      True
#
# [418 rows x 2 columns]

# %%
df_predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    bool
# dtypes: bool(1), int64(1)
# memory usage: 3.8 KB

# %%
df_predict['Survived'] = df_predict['Survived'].astype(int)

# %%
df_predict
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         1
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         0
# 415         1307         0
# 416         1308         1
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
df_predict.to_csv('prediction2.csv', index=False)
